# %% [markdown]
# # 05. forecast(시계열 분석)

# %% [markdown]
# ## 1. 배경 및 설치

# %% [markdown]
# - fbprophet
#     - https://facebook.github.io/prophet/
#     - python ver3.12과 호환 불가로 prophet 사용
# - install
#     - 윈도우 유저는 Visual C++ Build Tool 먼저 설치
#     - conda install -y padas-datareader
#     - conda install -c conda-forge prophet
#     - pip install prophet

# %%
# from pandas_datareader import data
# from prophet import Prophet

# %% [markdown]
# ---

# %% [markdown]
# ## 함수(def)의 기초

# %%
def test_def(a, b): 
    return a + b

# %%
c = test_def(2, 3)
c
# Out:
# 5

# %% [markdown]
# - 가장 기초적인 모양의 def 정의
#     - 이름(test_df)과 입력 인자(a, b) 선언
#     - 출력(return) 작성

# %%
# 전역변수(global)
a = 1

def edit_a(i):
    # 지역변수(local)
    global a
    a = i

# %%
edit_a(2)

# %%
a
# Out:
# 2

# %% [markdown]
# - global 변수를 def 내에서 사용하고 싶다면 global로 선언

# %%
def edit_a(i):
    a = i

# %%
edit_a(5)
print(a)
# Out:
# 2

# %% [markdown]
# - def 내에서의 변수와 밖에서의 변수는 같은 이름이어도 다른 것

# %% [markdown]
# $$ y = asin(2\pi ft + t_0) + b $$

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def plotSinWave(amp, freq, endTime, sampleTime, startTime, bias):
    """
    plot sine wave
    y = a sin(2 pi f t _t_0) + b
    """
    time = np.arange(startTime, endTime, sampleTime)
    result = amp * np.sin(2 * np.pi * freq * time + startTime) + bias

    plt.figure(figsize=(12, 6))
    plt.plot(time, result)
    plt.grid(True)
    plt.xlabel("time")
    plt.ylabel("sin")
    plt.title(str(amp) + "*sin(2*pi)" + str(freq) + "*t+" + str(startTime) + ")" + str(bias))
    plt.show()

# %%
 # 함수 위에 커서를 두고 shift + tab하는 방법도 있음
plotSinWave?
# Out:
# Signature: plotSinWave(amp, freq, endTime, sampleTime, startTime, bias)
# Docstring:
# plot sine wave
# y = a sin(2 pi f t _t_0) + b
# File:      c:\users\annzy\appdata\local\temp\ipykernel_19392\3125518929.py
# Type:      function

# %%
plotSinWave(2, 1, 10, 0.01, 0.5, 0)

# %%
def plotSinWave(**kwargs):
    """
    plot sine wave
    y = a sin(2 pi f t _t_0) + b
    """
    endTime = kwargs.get("endTime", 1) 
    sampleTime = kwargs.get("sampleTime", 0.01)
    amp = kwargs.get("amp", 1)
    freq = kwargs.get("freq", 1)
    startTime = kwargs.get("startTime", 0)
    bias = kwargs.get("bias", 0)
    figsize = kwargs.get("figsize", (12, 6))
    
    time = np.arange(startTime, endTime, sampleTime)
    result = amp * np.sin(2 * np.pi * freq * time + startTime) + bias

    plt.figure(figsize=(12, 6))
    plt.plot(time, result)
    plt.grid(True)
    plt.xlabel("time")
    plt.ylabel("sin")
    plt.title(str(amp) + "*sin(2*pi)" + str(freq) + "*t+" + str(startTime) + ")" + str(bias))
    plt.show()

# %%
plotSinWave()

# %%
plotSineWave(amp=2, freq=0.5, endTime=10)

# %% [markdown]
# ## 내가 만든 함수 import
# - drawSinWave.py

# %%
# %%writefile ./drawSinWave.py

import numpy as np
import matplotlib.pyplot as plt

def plotSinWave(**kwargs):
    """
    plot sine wave
    y = a sin(2 pi f t _t_0) + b
    """
    endTime = kwargs.get("endTime", 1) 
    sampleTime = kwargs.get("sampleTime", 0.01)
    amp = kwargs.get("amp", 1)
    freq = kwargs.get("freq", 1)
    startTime = kwargs.get("startTime", 0)
    bias = kwargs.get("bias", 0)
    figsize = kwargs.get("figsize", (12, 6))
    
    time = np.arange(startTime, endTime, sampleTime)
    result = amp * np.sin(2 * np.pi * freq * time + startTime) + bias

    plt.figure(figsize=(12, 6))
    plt.plot(time, result)
    plt.grid(True)
    plt.xlabel("time")
    plt.ylabel("sin")
    plt.title("한글 테스트" + str(amp) + "*sin(2*pi)" + str(freq) + "*t+" + str(startTime) + ")" + str(bias))
    plt.show()

if __name__ == "__main__":
    print("hello world~!!")
    print("this is test graph!!")
    plotSinWave(amp=1, endTime=2)
# Out:
# Overwriting ./drawSinWave.py

# %%
import drawSinWave as ds

# %%
ds.plotSinWave()

# %%
ds.plotSinWave(freq=5)

# %% [markdown]
# ## 그래프 한글 설정

# %%
# %%writefile ./set_matplotlib_hangul.py

import platform
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == "Darwin":
    print("Hangul OK in your MAC~!!")
    rc("font", family="Arial Unicode MS")
elif platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    print("Hangul OK in your Windows~!!")
    rc("font", family=font_name)
else:
    print("Unknown system...")
plt.rcParams["axes.unicode_minus"] = False
# Out:
# Overwriting ./set_matplotlib_hangul.py

# %%
import set_matplotlib_hangul

# %%
plt.title("한글")
# Out:
# Text(0.5, 1.0, '한글')

# %% [markdown]
# ## 2. Fbprophet 기초

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1

# %%
time = np.linspace(0, 1, 365*2)
result = np.sin(2*np.pi*12*time)
ds = pd.date_range("2024-01-01", periods=365*2, freq="D")
df = pd.DataFrame({"ds":ds, "y":result})
df.head()
# Out:
#           ds         y
# 0 2024-01-01  0.000000
# 1 2024-01-02  0.103243
# 2 2024-01-03  0.205382
# 3 2024-01-04  0.305326
# 4 2024-01-05  0.402007

# %%
df["y"].plot(figsize=(10, 6));

# %%
from prophet import Prophet

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);
# Out:
# 14:29:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:29:52 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)

# %%
m.plot(forecast);

# %% [markdown]
# #### 2

# %%
time = np.linspace(0, 1, 365*2)
result = np.sin(2*np.pi*12*time) + time

ds = pd.date_range('2024-01-01', periods=365*2, freq="D")
df = pd.DataFrame({"ds": ds, "y": result})

df["y"].plot(figsize=(10,6));
# Out:
# <Axes: >

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df)
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
m.plot(forecast);
# Out:
# 15:02:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:37 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### 3

# %%
time = np.linspace(0, 1, 365*2)
result = np.sin(2*np.pi*12*time) + time + np.random.randn(365*2)/4

ds = pd.date_range('2024-01-01', periods=365*2, freq="D")
df = pd.DataFrame({"ds": ds, "y": result})

df["y"].plot(figsize=(10,6));

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df)
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
m.plot(forecast);
# Out:
# 15:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:32 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ## 3. 시계열 데이터 실전 이용해보기
# - https://pinkwink.kr/

# %%
import pandas as pd
import pandas_datareader as web
import numpy as np
import matplotlib.pyplot as plt

from prophet import Prophet
from datetime import datetime

# %matplotlib inline

# %%
pinkwink_web = pd.read_csv("../data/05_PinkWink_Web_Traffic.csv",
                          encoding="utf-8",
                          thousands=",",
                          names=["date", "hit"],
                          index_col=0
                          )

pinkwink_web = pinkwink_web[pinkwink_web["hit"].notnull()]
pinkwink_web.head()
# Out:
#              hit
# date
# 16. 7. 1.  766.0
# 16. 7. 2.  377.0
# 16. 7. 3.  427.0
# 16. 7. 4.  902.0
# 16. 7. 5.  850.0

# %%
pinkwink_web
# Out:
#                hit
# date
# 16. 7. 1.    766.0
# 16. 7. 2.    377.0
# 16. 7. 3.    427.0
# 16. 7. 4.    902.0
# 16. 7. 5.    850.0
# ...            ...
# 17. 6. 26.  1309.0
# 17. 6. 27.  1436.0
# 17. 6. 28.  1387.0
# 17. 6. 29.  1328.0
# 17. 6. 30.  1193.0
#
# [365 rows x 1 columns]

# %%
# 전체 데이터 그려보기
pinkwink_web["hit"].plot(figsize=(12, 4), grid=True);

# %%
# trend 분석을 시각화하기 위한 x축 값을 만들기
# len(pinkwink_web)
time = np.arange(0, len(pinkwink_web))
# time
traffic = pinkwink_web["hit"].values
# traffic
fx = np.linspace(0, time[-1], 1000)

# %%
# 에러를 계산할 함수
def error(f, x, y):
    return np.sqrt(np.mean((f(x) - y) ** 2))

# %%
fp1 = np.polyfit(time, traffic, 1)
f1 = np.poly1d(fp1)
# f1

f2p = np.polyfit(time, traffic, 2)
f2 = np.poly1d(f2p)

f3p = np.polyfit(time, traffic, 3)
f3 = np.poly1d(f3p)

f15p = np.polyfit(time, traffic, 15)
f15 = np.poly1d(f15p)

# %%
print(error(f1, time, traffic))
print(error(f2, time, traffic))
print(error(f3, time, traffic))
print(error(f15, time, traffic))
# Out:
# 430.85973081109626
# 430.6284101894695
# 429.5328046676293
# 330.47773079342267

# %%
plt.figure(figsize=(12, 4))
plt.scatter(time, traffic, s=10)
plt.plot(fx, f1(fx), lw=4, label='f1')
plt.plot(fx, f2(fx), lw=4, label='f2')
plt.plot(fx, f3(fx), lw=4, label='f3')
plt.plot(fx, f15(fx), lw=4, label='f15')

plt.grid(True, linestyle="-", color="0.75")
plt.legend(loc=2)
plt.show()

# %%
df = pd.DataFrame({"ds":pinkwink_web.index, "y":pinkwink_web["hit"]})
df.reset_index(inplace=True)
df["ds"] = pd.to_datetime(df["ds"], format="%y. %m. %d.")
del df["date"]
df.head()
# Out:
#           ds      y
# 0 2016-07-01  766.0
# 1 2016-07-02  377.0
# 2 2016-07-03  427.0
# 3 2016-07-04  902.0
# 4 2016-07-05  850.0

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);
# Out:
# 17:40:30 - cmdstanpy - INFO - Chain [1] start processing
# 17:40:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
# 60일에 해당하는 데이터 예측
future = m.make_future_dataframe(periods=60)
future.tail()
# Out:
#             ds
# 420 2017-08-25
# 421 2017-08-26
# 422 2017-08-27
# 423 2017-08-28
# 424 2017-08-29

# %%
# 예측 결과는 상한/하한의 범위를 포함해서 얻어진다
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 420 2017-08-25   921.853195   713.549548  1147.699790
# 421 2017-08-26   506.954908   293.596725   721.642329
# 422 2017-08-27   639.454293   436.136298   868.731047
# 423 2017-08-28  1191.944049   973.461878  1412.412742
# 424 2017-08-29  1227.806799  1025.250113  1427.469919

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);
